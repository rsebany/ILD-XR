# %% [markdown]
# <style>
#   :root {
#     --brand: #0d9488;
#     --brand-dark: #0f766e;
#     --brand-light: #ccfbf1;
#     --ink: #0f172a;
#     --muted: #64748b;
#     --surface: #f8fafc;
#     --border: #e2e8f0;
#     --accent: #6366f1;
#   }
#   .nb-hero {
#     background: linear-gradient(135deg, #0f766e 0%, #134e4a 50%, #1e1b4b 100%);
#     color: #fff;
#     border-radius: 16px;
#     padding: 2.5rem 2rem;
#     margin: 0 0 1.5rem 0;
#     box-shadow: 0 20px 40px rgba(15, 118, 110, 0.25);
#   }
#   .nb-hero h1 {
#     font-size: 2rem;
#     font-weight: 700;
#     margin: 0 0 0.5rem 0;
#     letter-spacing: -0.02em;
#     border: none !important;
#     color: #fff !important;
#   }
#   .nb-hero p {
#     font-size: 1.05rem;
#     opacity: 0.92;
#     margin: 0 0 1.25rem 0;
#     line-height: 1.6;
#     max-width: 720px;
#   }
#   .nb-badges { display: flex; flex-wrap: wrap; gap: 0.5rem; }
#   .nb-badge {
#     display: inline-block;
#     background: rgba(255,255,255,0.15);
#     border: 1px solid rgba(255,255,255,0.25);
#     border-radius: 999px;
#     padding: 0.25rem 0.85rem;
#     font-size: 0.78rem;
#     font-weight: 600;
#     letter-spacing: 0.03em;
#     text-transform: uppercase;
#   }
#   .nb-section {
#     border-left: 4px solid var(--brand);
#     padding: 0.75rem 0 0.75rem 1.25rem;
#     margin: 2rem 0 1rem 0;
#   }
#   .nb-section h2 {
#     color: var(--ink) !important;
#     font-size: 1.45rem !important;
#     font-weight: 700 !important;
#     margin: 0 !important;
#     border: none !important;
#   }
#   .nb-section p {
#     color: var(--muted);
#     margin: 0.35rem 0 0 0;
#     font-size: 0.95rem;
#   }
#   .nb-card {
#     background: var(--surface);
#     border: 1px solid var(--border);
#     border-radius: 12px;
#     padding: 1.25rem 1.5rem;
#     margin: 1rem 0;
#   }
#   .nb-card h3 {
#     color: var(--brand-dark) !important;
#     font-size: 1rem !important;
#     margin: 0 0 0.75rem 0 !important;
#     border: none !important;
#   }
#   .nb-grid {
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(180px, 1fr));
#     gap: 0.75rem;
#   }
#   .nb-stat {
#     background: #fff;
#     border: 1px solid var(--border);
#     border-radius: 10px;
#     padding: 0.85rem 1rem;
#     text-align: center;
#   }
#   .nb-stat .val {
#     font-size: 1.35rem;
#     font-weight: 700;
#     color: var(--brand-dark);
#   }
#   .nb-stat .lbl {
#     font-size: 0.75rem;
#     color: var(--muted);
#     text-transform: uppercase;
#     letter-spacing: 0.04em;
#     margin-top: 0.15rem;
#   }
#   .nb-toc {
#     background: #fff;
#     border: 1px solid var(--border);
#     border-radius: 12px;
#     padding: 1.25rem 1.5rem;
#     margin: 1rem 0 2rem 0;
#   }
#   .nb-toc h3 {
#     margin: 0 0 0.75rem 0 !important;
#     font-size: 0.85rem !important;
#     text-transform: uppercase;
#     letter-spacing: 0.06em;
#     color: var(--muted) !important;
#     border: none !important;
#   }
#   .nb-toc ol {
#     margin: 0;
#     padding-left: 1.25rem;
#     line-height: 2;
#   }
#   .nb-toc a {
#     color: var(--brand-dark);
#     text-decoration: none;
#     font-weight: 500;
#   }
#   .nb-toc a:hover { text-decoration: underline; }
#   .nb-callout {
#     border-radius: 10px;
#     padding: 1rem 1.25rem;
#     margin: 1rem 0;
#     font-size: 0.92rem;
#     line-height: 1.55;
#   }
#   .nb-callout.info {
#     background: #eff6ff;
#     border: 1px solid #bfdbfe;
#     color: #1e40af;
#   }
#   .nb-callout.tip {
#     background: var(--brand-light);
#     border: 1px solid #99f6e4;
#     color: var(--brand-dark);
#   }
#   .nb-pipeline {
#     display: flex;
#     flex-wrap: wrap;
#     align-items: center;
#     gap: 0.5rem;
#     margin: 1rem 0;
#   }
#   .nb-step {
#     background: #fff;
#     border: 1px solid var(--border);
#     border-radius: 8px;
#     padding: 0.5rem 0.85rem;
#     font-size: 0.85rem;
#     font-weight: 500;
#     color: var(--ink);
#   }
#   .nb-arrow { color: var(--muted); font-size: 1.1rem; }
#   table.nb-table {
#     width: 100%;
#     border-collapse: collapse;
#     font-size: 0.9rem;
#     margin: 0.75rem 0;
#   }
#   table.nb-table th {
#     background: var(--brand-dark);
#     color: #fff;
#     padding: 0.6rem 1rem;
#     text-align: left;
#     font-weight: 600;
#   }
#   table.nb-table td {
#     padding: 0.55rem 1rem;
#     border-bottom: 1px solid var(--border);
#   }
#   table.nb-table tr:nth-child(even) td { background: var(--surface); }
#   .nb-footer {
#     text-align: center;
#     color: var(--muted);
#     font-size: 0.82rem;
#     margin-top: 2.5rem;
#     padding-top: 1.5rem;
#     border-top: 1px solid var(--border);
#   }
# </style>
#
# <div class="nb-hero">
#   <h1>ILD-XR · Fine-Tuning 3D U-Net</h1>
#   <p>
#     Second-stage training that refines a pre-trained model on lesion-centered patches
#   with dual-channel input (HU + local variance). Uses warm-start weights, multi-GPU
#   training, and test-time augmentation for robust ILD pattern segmentation.
#   Trained on the <strong>MedGIFT</strong> interstitial lung disease database.
#   </p>
#   <div class="nb-badges">
#     <span class="nb-badge">MedGIFT ILD DB</span>
#     <span class="nb-badge">Fine-Tuning</span>
#     <span class="nb-badge">2-Channel Input</span>
#     <span class="nb-badge">DataParallel</span>
#     <span class="nb-badge">TTA</span>
#   </div>
# </div>

# %% [markdown]
# <div class="nb-toc">
#   <h3>Contents</h3>
#   <ol>
#     <li><a href="#overview">Overview &amp; Pipeline</a></li>
#     <li><a href="#setup">Environment Setup</a></li>
#     <li><a href="#config">Configuration</a></li>
#     <li><a href="#loss">Loss Functions</a></li>
#     <li><a href="#architecture">Model Architecture</a></li>
#     <li><a href="#preprocessing">Preprocessing</a></li>
#     <li><a href="#dataloading">Data Loading</a></li>
#     <li><a href="#dataset">Dataset, TTA &amp; Multi-GPU</a></li>
#     <li><a href="#training">Training</a></li>
#     <li><a href="#results">Results</a></li>
#   </ol>
# </div>

# %% [markdown]
# <a id="overview"></a>
# <div class="nb-section">
#   <h2>1 · Overview &amp; Pipeline</h2>
#   <p>Warm-start fine-tuning with lesion-focused patch mining and dual-input encoding.</p>
# </div>
#
# <div class="nb-card">
#   <h3>Dataset — MedGIFT ILD Database</h3>
#   <p style="margin:0; color:#64748b; font-size:0.92rem; line-height:1.6;">
#     Fine-tuning data comes from the <strong>MedGIFT</strong> (Medical Image and Data Processing Group)
#     interstitial lung disease collection: chest CT volumes with expert ROI annotations for
#     GGO, reticulation, and consolidation. Thirteen patients are excluded via
#     <code>EXCLUDED_PATIENTS</code> due to known quality issues.
#   </p>
# </div>
#
# <div class="nb-card">
#   <h3>Fine-Tuning Pipeline</h3>
#   <div class="nb-pipeline">
#     <span class="nb-step">Pre-trained weights</span>
#     <span class="nb-arrow">→</span>
#     <span class="nb-step">Lesion-centered patches</span>
#     <span class="nb-arrow">→</span>
#     <span class="nb-step">HU + variance channels</span>
#     <span class="nb-arrow">→</span>
#     <span class="nb-step">GDL + Focal Tversky loss</span>
#     <span class="nb-arrow">→</span>
#     <span class="nb-step">TTA validation</span>
#     <span class="nb-arrow">→</span>
#     <span class="nb-step">best_finetuned_multiclass_model.pth</span>
#   </div>
# </div>
#
# <div class="nb-callout info">
#   <strong>vs. initial training:</strong> This notebook adds a local variance texture channel,
#   lesion-centered sampling, warm-start from a prior checkpoint, ramped deep supervision,
#   gradient clipping, and validation with test-time augmentation (TTA).
# </div>

# %% [markdown]
# <a id="setup"></a>
# <div class="nb-section">
#   <h2>2 · Environment Setup</h2>
#   <p>Import dependencies and suppress non-critical warnings.</p>
# </div>

# %%
import os
import warnings

import numpy as np
import pydicom
import SimpleITK as sitk
import torch
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from scipy import ndimage
from scipy.ndimage import uniform_filter
from skimage import morphology, measure, segmentation
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="config"></a>
# <div class="nb-section">
#   <h2>3 · Configuration</h2>
#   <p>Hyperparameters, paths, and per-class patch acceptance thresholds.</p>
# </div>
#
# <div class="nb-callout info">
#   <strong>Data source:</strong> <code>DATA_DIR</code> points to the MedGIFT ILD database
#   (<code>ILD_DB_volumeROIs</code>). <code>PREVIOUS_MODEL_PATH</code> provides warm-start weights.
# </div>
#
# <div class="nb-grid">
#   <div class="nb-stat"><div class="val">32 × 128 × 128</div><div class="lbl">Patch Size</div></div>
#   <div class="nb-stat"><div class="val">60</div><div class="lbl">Epochs</div></div>
#   <div class="nb-stat"><div class="val">8</div><div class="lbl">Batch Size</div></div>
#   <div class="nb-stat"><div class="val">2</div><div class="lbl">Input Channels</div></div>
# </div>

# %%
# MedGIFT ILD database — DICOM CT volumes + expert ROI masks
DATA_DIR = "/kaggle/input/datasets/romualdosebany/intertitial-lung-disease/ILD_DB/ILD_DB_volumeROIs"
PREVIOUS_MODEL_PATH = "/kaggle/input/datasets/steavenmamizara/fine-tuning-unet/best_finetuned_multiclass_model (1).pth"
FINE_TUNED_MODEL_PATH = "best_finetuned_multiclass_model.pth"

PATCH_DEPTH, PATCH_HEIGHT, PATCH_WIDTH = 32, 128, 128
BATCH_SIZE = 8
NUM_EPOCHS = 60
NUM_CLASSES = 4
IN_CHANNELS = 2  # HU intensity + local variance channel

MIN_GGO_VOXELS = 200
MIN_RET_VOXELS = 100
MIN_CONS_VOXELS = 80
BACKGROUND_KEEP_PROB = 0.08

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

EXCLUDED_PATIENTS = {
    "CT-INSPIRIUM-8873", "CT-INSPIRIUM-8871", "CT-INSPIRIUM-2950", "CT-INSPIRIUM-2951",
    "CT-INSPIRIUM-6410", "CT-INSPIRIUM-6409", "CT-series-5652", "CT-INSPIRIUM-3550",
    "CT--0002", "CT-INSPIRIUM-5842", "CT-INSPIRIUM-5841", "CT-INSPIRIUM-7605",
    "CT-INSPIRIUM-1841",
}

print(f"Device: {DEVICE}")
print(f"Input channels: {IN_CHANNELS} (HU + variance)")

# %% [markdown]
# <a id="loss"></a>
# <div class="nb-section">
#   <h2>4 · Loss Functions</h2>
#   <p>Combined CrossEntropy, Generalized Dice, and Focal Tversky for class imbalance.</p>
# </div>
#
# <div class="nb-card">
#   <h3>Loss Configuration</h3>
#   <table class="nb-table">
#     <tr><th>Loss</th><th>Role</th></tr>
#     <tr><td>CrossEntropy</td><td>Class weights [0.5, 8, 6, 4] — reduced GGO weight vs. initial training</td></tr>
#     <tr><td>Generalized Dice</td><td>Inverse-frequency weighting per class</td></tr>
#     <tr><td>Focal Tversky</td><td>α=0.3, β=0.7, γ=2.0 — penalises missed lesions</td></tr>
#   </table>
# </div>

# %%
class GeneralizedDiceLoss(nn.Module):
    def __init__(self, n_classes=4):
        super().__init__()
        self.n_classes = n_classes

    def forward(self, inputs, targets):
        probs = F.softmax(inputs, dim=1)
        targets_one_hot = F.one_hot(targets, num_classes=self.n_classes).permute(0, 4, 1, 2, 3).float()

        counts = targets_one_hot.sum(dim=(0, 2, 3, 4))
        weights = 1.0 / (counts ** 2 + 1e-6)
        weights = weights / weights.sum()

        gdl = 0.0
        for c in range(self.n_classes):
            p_c = probs[:, c]
            g_c = targets_one_hot[:, c]
            intersection = (p_c * g_c).sum()
            union = p_c.sum() + g_c.sum()
            gdl += weights[c] * (1.0 - (2.0 * intersection + 1e-6) / (union + 1e-6))
        return gdl


class MultiClassFocalTverskyLoss(nn.Module):
    def __init__(self, n_classes=4, alpha=0.3, beta=0.7, gamma=2.0):
        super().__init__()
        self.n_classes = n_classes
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def forward(self, inputs, targets):
        probs = F.softmax(inputs, dim=1)
        targets_one_hot = F.one_hot(targets, num_classes=self.n_classes).permute(0, 4, 1, 2, 3).float()

        tversky_loss = 0.0
        for c in range(1, self.n_classes):
            p_c = probs[:, c]
            g_c = targets_one_hot[:, c]
            tp = (p_c * g_c).sum()
            fp = (p_c * (1.0 - g_c)).sum()
            fn = ((1.0 - p_c) * g_c).sum()
            tversky_idx = (tp + 1e-6) / (tp + self.alpha * fp + self.beta * fn + 1e-6)
            tversky_loss += (1.0 - tversky_idx) ** (1.0 / self.gamma)
        return tversky_loss / (self.n_classes - 1)

# %% [markdown]
# <a id="architecture"></a>
# <div class="nb-section">
#   <h2>5 · Model Architecture</h2>
#   <p>3D residual U-Net with deep supervision — extended to 2 input channels for fine-tuning.</p>
# </div>
#
# <div class="nb-card">
#   <h3>UNet3DDeepSup (in_channels=2)</h3>
#   <table class="nb-table">
#     <tr><th>Component</th><th>Detail</th></tr>
#     <tr><td>Encoder</td><td>2 → 32 → 64 → 128 (ResidualBlock3D)</td></tr>
#     <tr><td>Bottleneck</td><td>128 → 256</td></tr>
#     <tr><td>Decoder</td><td>256 → 128 → 64 → 32 with skip connections</td></tr>
#     <tr><td>Deep supervision</td><td>2 auxiliary heads, ramped weight during training</td></tr>
#   </table>
# </div>

# %%
class ResidualBlock3D(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv3d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
        )
        self.shortcut = nn.Conv3d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()

    def forward(self, x):
        return F.relu(self.conv(x) + self.shortcut(x))


class UNet3DDeepSup(nn.Module):
    def __init__(self, n_classes=4, in_channels=2):
        super().__init__()
        self.enc1 = ResidualBlock3D(in_channels, 32)
        self.enc2 = ResidualBlock3D(32, 64)
        self.enc3 = ResidualBlock3D(64, 128)
        self.pool = nn.MaxPool3d(2)
        self.bottleneck = ResidualBlock3D(128, 256)

        self.up3 = nn.ConvTranspose3d(256, 128, 2, stride=2)
        self.dec3 = ResidualBlock3D(256, 128)
        self.ds3 = nn.Conv3d(128, n_classes, 1)

        self.up2 = nn.ConvTranspose3d(128, 64, 2, stride=2)
        self.dec2 = ResidualBlock3D(128, 64)
        self.ds2 = nn.Conv3d(64, n_classes, 1)

        self.up1 = nn.ConvTranspose3d(64, 32, 2, stride=2)
        self.dec1 = ResidualBlock3D(64, 32)
        self.final = nn.Conv3d(32, n_classes, 1)

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        b = self.bottleneck(self.pool(e3))

        d3 = self.dec3(torch.cat([F.interpolate(self.up3(b), size=e3.shape[2:]), e3], dim=1))
        d2 = self.dec2(torch.cat([F.interpolate(self.up2(d3), size=e2.shape[2:]), e2], dim=1))
        d1 = self.dec1(torch.cat([F.interpolate(self.up1(d2), size=e1.shape[2:]), e1], dim=1))

        if self.training:
            out_ds2 = F.interpolate(self.ds2(d2), size=d1.shape[2:], mode='trilinear', align_corners=False)
            out_ds3 = F.interpolate(self.ds3(d3), size=d1.shape[2:], mode='trilinear', align_corners=False)
            return self.final(d1), out_ds2, out_ds3
        return self.final(d1)

# %% [markdown]
# <a id="preprocessing"></a>
# <div class="nb-section">
#   <h2>6 · Preprocessing</h2>
#   <p>Lung masking, HU normalization, and local variance channel for GGO texture cues.</p>
# </div>
#
# <div class="nb-callout tip">
#   The <strong>variance channel</strong> captures local HU standard deviation — GGO appears as
#   moderate haze distinct from normal lung (low variance) and consolidation (high HU, low variance).
# </div>

# %%
def resample_to_isotropic(volume, spacing, is_mask=False):
    image = sitk.GetImageFromArray(volume.transpose(2, 0, 1))
    image.SetSpacing(spacing)
    new_spacing = [1.0, 1.0, 1.0]
    original_size = image.GetSize()
    original_spacing = image.GetSpacing()
    new_size = [
        int(round(s * (os_ / ns)))
        for s, os_, ns in zip(original_size, original_spacing, new_spacing)
    ]
    resampler = sitk.ResampleImageFilter()
    resampler.SetSize(new_size)
    resampler.SetOutputSpacing(new_spacing)
    resampler.SetInterpolator(sitk.sitkNearestNeighbor if is_mask else sitk.sitkLinear)
    return sitk.GetArrayFromImage(resampler.Execute(image)).transpose(1, 2, 0)


def extract_lung_mask(slice_2d):
    try:
        binary = slice_2d < -400
        cleared = morphology.remove_small_objects(binary, min_size=100)
        cleared = segmentation.clear_border(cleared)
        labels = measure.label(cleared)
        regions = measure.regionprops(labels)
        if not regions:
            return np.ones_like(slice_2d, dtype=np.float32)
        regions.sort(key=lambda x: x.area, reverse=True)
        mask = np.zeros_like(slice_2d)
        for rg in regions[:2]:
            mask[labels == rg.label] = 1
        return ndimage.binary_fill_holes(mask).astype(np.float32)
    except Exception:
        return np.ones_like(slice_2d, dtype=np.float32)


def add_variance_channel(vol, radius=3):
    """Local HU standard deviation map — texture cue for GGO detection."""
    kernel = radius * 2 + 1
    vol_f64 = vol.astype(np.float64)
    mean = uniform_filter(vol_f64, size=kernel)
    mean_sq = uniform_filter(vol_f64 ** 2, size=kernel)
    var = np.sqrt(np.maximum(mean_sq - mean ** 2, 0)).astype(np.float32)
    return var / (var.max() + 1e-6)


def preprocess_volume(volume):
    masked_vol = np.zeros_like(volume, dtype=np.float32)
    for i in range(volume.shape[2]):
        m = extract_lung_mask(volume[:, :, i])
        masked_vol[:, :, i] = volume[:, :, i] * m

    lower, upper = -1350, 150
    masked_vol = np.clip(masked_vol, lower, upper)
    hu_norm = ((masked_vol - lower) / (upper - lower)).astype(np.float32)
    variance = add_variance_channel(hu_norm)
    return np.stack([hu_norm, variance], axis=-1)

# %% [markdown]
# <a id="dataloading"></a>
# <div class="nb-section">
#   <h2>7 · Data Loading</h2>
#   <p>Load DICOM CT + ROI masks per patient; returns dual-channel volume and label map.</p>
# </div>

# %%
def load_patient_data(patient_path):
    patient_id = os.path.basename(patient_path)
    if patient_id in EXCLUDED_PATIENTS:
        return None, None

    ct_files = sorted([
        os.path.join(patient_path, f)
        for f in os.listdir(patient_path)
        if f.lower().endswith('.dcm')
    ])
    slices, spacing = [], None

    for i, f in enumerate(ct_files):
        try:
            ds = pydicom.dcmread(f)
            if i == 0:
                spacing = [
                    float(ds.PixelSpacing[0]),
                    float(ds.PixelSpacing[1]),
                    float(getattr(ds, 'SliceThickness', 1.0)),
                ]
            img = ds.pixel_array.astype(np.float32)
            if hasattr(ds, 'RescaleSlope'):
                img = img * ds.RescaleSlope + ds.RescaleIntercept
            slices.append(img)
        except Exception:
            continue

    mask_path = os.path.join(patient_path, 'roi_mask')
    masks = []
    if os.path.exists(mask_path):
        for f in sorted(os.listdir(mask_path)):
            if f.startswith('.'):
                continue
            try:
                full_m = os.path.join(mask_path, f)
                if f.endswith('.dcm'):
                    m = pydicom.dcmread(full_m).pixel_array
                else:
                    m = np.array(Image.open(full_m).convert('L'))
                m = np.clip(np.round(m), 0, NUM_CLASSES - 1)
                masks.append(m.astype(np.float32))
            except Exception:
                continue

    if not slices or not masks:
        return None, None

    min_d = min(len(slices), len(masks))
    vol = np.stack(slices, axis=2)[:, :, :min_d]
    mask = np.stack(masks, axis=2)[:, :, :min_d]

    if spacing:
        vol = resample_to_isotropic(vol, spacing, is_mask=False)
        mask = resample_to_isotropic(mask, spacing, is_mask=True)
        mask = np.clip(np.round(mask), 0, NUM_CLASSES - 1)

    if vol.shape[2] < PATCH_DEPTH:
        pad = PATCH_DEPTH - vol.shape[2]
        vol = np.pad(vol, ((0, 0), (0, 0), (0, pad)))
        mask = np.pad(mask, ((0, 0), (0, 0), (0, pad)))

    return preprocess_volume(vol), mask

# %% [markdown]
# <a id="dataset"></a>
# <div class="nb-section">
#   <h2>8 · Dataset, TTA &amp; Multi-GPU</h2>
#   <p>Augmented patch dataset, test-time augmentation for validation, and DataParallel helpers.</p>
# </div>

# %%
class ILDDataset(Dataset):
    def __init__(self, patches, augment=False):
        self.patches = patches
        self.augment = augment

    def __len__(self):
        return len(self.patches)

    def __getitem__(self, idx):
        v, m = self.patches[idx]
        v, m = v.copy(), m.copy()

        if self.augment:
            if np.random.rand() > 0.5:
                ax = np.random.choice([0, 1, 2])
                v = np.flip(v, ax).copy()
                m = np.flip(m, ax).copy()
            if np.random.rand() > 0.5:
                k = np.random.randint(1, 4)
                v = np.rot90(v, k, axes=(0, 1)).copy()
                m = np.rot90(m, k, axes=(0, 1)).copy()
            if np.random.rand() > 0.7:
                v[..., 0] = np.clip(v[..., 0] + np.random.uniform(-0.05, 0.05), 0, 1)
            if np.random.rand() > 0.8:
                v[..., 0] = np.clip(
                    v[..., 0] + np.random.normal(0, 0.02, v[..., 0].shape), 0, 1
                ).astype(np.float32)

        v_tensor = torch.FloatTensor(v).permute(3, 2, 0, 1)
        m_tensor = torch.LongTensor(m.astype(np.int64)).permute(2, 0, 1)
        return v_tensor, m_tensor


def predict_with_tta(model, vol_tensor):
    """Test-time augmentation: average predictions over axis flips."""
    flip_axes = [None, [2], [3], [4], [2, 3]]
    preds = []
    with torch.no_grad():
        for axes in flip_axes:
            v = vol_tensor.flip(axes) if axes is not None else vol_tensor
            logits = model(v)
            prob = F.softmax(logits, dim=1)
            prob = prob.flip(axes) if axes is not None else prob
            preds.append(prob)
    return torch.stack(preds).mean(0).argmax(1)


def get_model_state(model):
    return model.module.state_dict() if isinstance(model, nn.DataParallel) else model.state_dict()


def load_state_into_model(model, state_dict):
    """Shape-checked partial load — safe across in_channels change."""
    current = get_model_state(model)
    compatible = {k: v for k, v in state_dict.items() if k in current and current[k].shape == v.shape}
    current.update(compatible)
    if isinstance(model, nn.DataParallel):
        model.module.load_state_dict(current)
    else:
        model.load_state_dict(current)
    return len(compatible), len(state_dict) - len(compatible)

# %% [markdown]
# <a id="training"></a>
# <div class="nb-section">
#   <h2>9 · Training</h2>
#   <p>Lesion-centered patch mining, warm-start, multi-GPU training, and TTA validation.</p>
# </div>
#
# <div class="nb-callout info">
#   <strong>Patient-level split (85% / 15%):</strong> Train and validation sets are built from disjoint
#   patients <em>before</em> patch mining, preventing slice-level data leakage.
# </div>
#
# <div class="nb-callout tip">
#   Run this cell to start fine-tuning. Validation Dice uses TTA from epoch 1 for realistic metrics.
# </div>

# %%
def mine_patches_from_paths(patient_paths):
    """Lesion-centered patch mining from a list of patient directories."""
    patches = []
    for path in tqdm(patient_paths, leave=False):
        vol, mask = load_patient_data(path)
        if vol is None:
            continue

        ggo_indices = np.argwhere(mask == 1)
        ret_indices = np.argwhere(mask == 2)
        cons_indices = np.argwhere(mask == 3)
        n_samples = 120 if 'HRCT' in path else 70

        for _ in range(n_samples):
            rand_val = np.random.rand()
            if len(ggo_indices) > 0 and rand_val < 0.65:
                c = ggo_indices[np.random.choice(len(ggo_indices))]
            elif len(ret_indices) > 0 and rand_val < 0.85:
                c = ret_indices[np.random.choice(len(ret_indices))]
            elif len(cons_indices) > 0 and rand_val < 0.95:
                c = cons_indices[np.random.choice(len(cons_indices))]
            else:
                c = np.array([
                    np.random.randint(0, vol.shape[0]),
                    np.random.randint(0, vol.shape[1]),
                    np.random.randint(0, vol.shape[2]),
                ])

            y_c, x_c, z_c = c[0], c[1], c[2]
            z_start = max(0, min(z_c - PATCH_DEPTH // 2, vol.shape[2] - PATCH_DEPTH))
            y_start = max(0, min(y_c - PATCH_HEIGHT // 2, vol.shape[0] - PATCH_HEIGHT))
            x_start = max(0, min(x_c - PATCH_WIDTH // 2, vol.shape[1] - PATCH_WIDTH))

            vp = vol[y_start:y_start + PATCH_HEIGHT, x_start:x_start + PATCH_WIDTH, z_start:z_start + PATCH_DEPTH, :]
            mp = mask[y_start:y_start + PATCH_HEIGHT, x_start:x_start + PATCH_WIDTH, z_start:z_start + PATCH_DEPTH]

            ggo_count = int(np.sum(mp == 1))
            ret_count = int(np.sum(mp == 2))
            cons_count = int(np.sum(mp == 3))
            accept = (
                ggo_count >= MIN_GGO_VOXELS
                or ret_count >= MIN_RET_VOXELS
                or cons_count >= MIN_CONS_VOXELS
                or np.random.rand() < BACKGROUND_KEEP_PROB
            )
            if accept:
                patches.append((vp, mp))
    return patches


def main():
    n_gpus = torch.cuda.device_count()
    print(f"Device: {DEVICE}")
    print(f"GPUs: {n_gpus} x {torch.cuda.get_device_name(0) if n_gpus > 0 else 'CPU'}")

    all_paths = [
        os.path.join(DATA_DIR, f)
        for f in os.listdir(DATA_DIR)
        if os.path.isdir(os.path.join(DATA_DIR, f)) and f != 'HRCT_pilot'
    ]
    hrct_dir = os.path.join(DATA_DIR, 'HRCT_pilot')
    if os.path.exists(hrct_dir):
        all_paths += [
            os.path.join(hrct_dir, f)
            for f in os.listdir(hrct_dir)
            if os.path.isdir(os.path.join(hrct_dir, f))
        ]

    # Split at patient level first to avoid data leakage across train/val patches.
    train_paths, val_paths = train_test_split(all_paths, test_size=0.15, random_state=42)

    print(f"Patients — train: {len(train_paths)} ({100 * len(train_paths) / len(all_paths):.0f}%), "
          f"val: {len(val_paths)} ({100 * len(val_paths) / len(all_paths):.0f}%)")

    print("Mining train patches...")
    train_p = mine_patches_from_paths(train_paths)
    print("Mining validation patches...")
    val_p = mine_patches_from_paths(val_paths)

    print(f"Patches — train: {len(train_p):,}, val: {len(val_p):,}")

    train_loader = DataLoader(
        ILDDataset(train_p, augment=True),
        batch_size=BATCH_SIZE, shuffle=True,
        num_workers=4, pin_memory=True, persistent_workers=True,
    )
    val_loader = DataLoader(
        ILDDataset(val_p, augment=False),
        batch_size=BATCH_SIZE,
        num_workers=4, pin_memory=True, persistent_workers=True,
    )

    model = UNet3DDeepSup(n_classes=NUM_CLASSES, in_channels=IN_CHANNELS).to(DEVICE)
    if n_gpus > 1:
        print(f"Enabling DataParallel across {n_gpus} GPUs")
        model = nn.DataParallel(model)

    if os.path.exists(PREVIOUS_MODEL_PATH):
        print("Warm start: loading compatible weights from previous model...")
        try:
            prev_state = torch.load(PREVIOUS_MODEL_PATH, map_location=DEVICE)
            loaded, skipped = load_state_into_model(model, prev_state)
            print(f"  Loaded: {loaded} layers | Skipped: {skipped} (shape mismatch on enc1 expected)")
        except Exception as e:
            print(f"Warm start failed: {e}. Starting fresh.")
    else:
        print("Previous model not found. Starting fresh.")

    optimizer = torch.optim.AdamW(model.parameters(), lr=8e-5, weight_decay=1e-5)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=4)

    crit_ce = nn.CrossEntropyLoss(weight=torch.tensor([0.5, 8.0, 6.0, 4.0]).to(DEVICE))
    crit_gdl = GeneralizedDiceLoss(n_classes=NUM_CLASSES)
    crit_tv = MultiClassFocalTverskyLoss(n_classes=NUM_CLASSES, alpha=0.3, beta=0.7, gamma=2.0)

    best_dice = 0.0
    print(f"\nStarting training — {NUM_EPOCHS} epochs | batch {BATCH_SIZE} | {n_gpus} GPU(s)\n")

    for epoch in range(NUM_EPOCHS):
        ds_weight = min(0.4, 0.1 + epoch * 0.015)

        model.train()
        epoch_loss = 0.0
        for v, m in tqdm(train_loader, desc=f"Epoch {epoch + 1:02d}/{NUM_EPOCHS} [train]", leave=False):
            v, m = v.to(DEVICE), m.to(DEVICE)
            optimizer.zero_grad()
            o1, o2, o3 = model(v)
            l1 = crit_ce(o1, m) + 1.00 * crit_tv(o1, m) + 1.00 * crit_gdl(o1, m)
            l2 = crit_ce(o2, m) + 0.50 * crit_tv(o2, m) + 0.50 * crit_gdl(o2, m)
            l3 = crit_ce(o3, m) + 0.25 * crit_tv(o3, m) + 0.25 * crit_gdl(o3, m)
            loss = l1 + ds_weight * l2 + (ds_weight * 0.5) * l3
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            epoch_loss += loss.item()

        avg_loss = epoch_loss / len(train_loader)

        model.eval()
        per_cls = np.zeros(NUM_CLASSES - 1)
        with torch.no_grad():
            for v, m in tqdm(val_loader, desc=f"Epoch {epoch + 1:02d}/{NUM_EPOCHS} [val]", leave=False):
                v, m = v.to(DEVICE), m.to(DEVICE)
                pred = predict_with_tta(model, v)
                for ci, c in enumerate(range(1, NUM_CLASSES)):
                    p_c = (pred == c)
                    m_c = (m == c)
                    dice_c = ((2.0 * (p_c & m_c).sum() + 1e-6) / (p_c.sum() + m_c.sum() + 1e-6)).item()
                    per_cls[ci] += dice_c

        per_cls /= len(val_loader)
        avg_dice = float(per_cls.mean())
        scheduler.step(avg_dice)

        print(
            f"Epoch {epoch + 1:02d}/{NUM_EPOCHS} | Loss: {avg_loss:.4f} | Dice: {avg_dice:.4f} | "
            f"GGO: {per_cls[0]:.4f} | Ret: {per_cls[1]:.4f} | Cons: {per_cls[2]:.4f} | "
            f"LR: {optimizer.param_groups[0]['lr']:.2e} | DS-w: {ds_weight:.3f}"
        )

        if avg_dice > best_dice:
            best_dice = avg_dice
            torch.save(get_model_state(model), FINE_TUNED_MODEL_PATH)
            print(f"  >>> New best saved — Dice = {best_dice:.4f} <<<")

    print(f"\nTraining complete. Peak validation Dice: {best_dice:.4f}")
    print(f"Model saved to: {FINE_TUNED_MODEL_PATH}")


if __name__ == "__main__":
    main()

# %% [markdown]
# <a id="results"></a>
# <div class="nb-section">
#   <h2>10 · Results</h2>
#   <p>Fine-tuning converges quickly thanks to warm-start weights and lesion-focused sampling.</p>
# </div>
#
# <div class="nb-grid">
#   <div class="nb-stat"><div class="val">0.8925</div><div class="lbl">Best Val Dice (TTA)</div></div>
#   <div class="nb-stat"><div class="val">Epoch 5</div><div class="lbl">Best Epoch</div></div>
#   <div class="nb-stat"><div class="val">2 x T4</div><div class="lbl">GPUs</div></div>
#   <div class="nb-stat"><div class="val">best_finetuned_multiclass_model.pth</div><div class="lbl">Checkpoint</div></div>
# </div>
#
# <div class="nb-card">
#   <h3>Per-Class Dice at Best Epoch</h3>
#   <table class="nb-table">
#     <tr><th>Class</th><th>Dice</th></tr>
#     <tr><td>GGO</td><td>0.9001</td></tr>
#     <tr><td>Reticulation</td><td>0.9269</td></tr>
#     <tr><td>Consolidation</td><td>0.8503</td></tr>
#   </table>
# </div>
#
# <div class="nb-footer">
#   ILD-XR · Fine-Tuning Pipeline · MedGIFT ILD Database · PyTorch 3D U-Net
# </div>
